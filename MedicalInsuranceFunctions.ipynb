# %%
def calculate_insurance_cost(name,age,sex,bmi,smoker,num_of_children):
  estimated_cost = 1000
  estimated_cost = 250*age - 128*sex + 370*bmi + 425*num_of_children + 24000*smoker - 12500
  output_message = name +"'s isurance cost is "+ str(estimated_cost)

  return estimated_cost, output_message
  #print(estimated_cost)
  #print("The estimated insurance cost for" + name + " is " + str(insurance_cost) + " dollars.")
def insurance_cost_difference(estimated_cost1,estimated_cost2):
  difference = abs(estimated_cost1-estimated_cost2)
  result="The difference in insurance cost is "+ str(difference)+" dollars."
  return difference + result
# Estimate Maria's insurance cost
#maria_insurance_cost = calculate_insurance_cost("Maria", 28,0,26.2,3,0)

#print("The estimated insurance cost for Maria is " + str(insurance_cost) + " dollars.")

# Estimate Omar's insurance cost 
#omar_insurance_cost = calculate_insurance_cost("Omar",35,22.2,0,1,0)

#amanda_insurance_cost= calculate_insurance_cost("Amanda",24,0,22.2,0,0)
#print("Maria's insurance cost "+str(maria_insurance_cost))
#print("Omar's insurance cost "+ str(omar_insurance_cost))
#print("Amanda's insurance cost "+str( amanda_insurance_cost))

#print("The estimated insurance cost for Omar is " + str(insurance_cost) + " dollars.")
# Out:
# This person's insurance cost is -104206.0 dollars.
# This person's insurance cost is -104206.0 dollars.
# The change in estimated cost for being male instead of female is 1147.0 dollars.
# SEXISM

# %%
# !git clone https://github.com/AmandaAlexopoulou/Medical-Insurance-Project
# Out:
# Cloning into 'Medical-Insurance-Project'...

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.azure',
#  '.bash_history',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.continuum',
#  '.dotnet',
#  '.eclipse',
#  '.git',
#  '.gitconfig',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.matplotlib',
#  '.node_repl_history',
#  '.p2',
#  '.packettracer',
#  '.ssh',
#  '.templateengine',
#  '.thumbnails',
#  '.viminfo',
#  '.virtual_documents',
#  '.vscode',
#  '.yarnrc',
#  '3D Objects',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'client',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'eclipse',
#  'eclipse-workspace',
#  'export_202511281508.csv',
#  'Favorites',
#  'HealthInsuranceCost.ipynb',
#  'IntelGraphicsProfiles',
#  'Jedi',
#  'Links',
#  'Local Settings',
#  'Medical-Insurance-Project',
#  'MedicalInsuranceFunctions.ipynb',
#  'Music',
#  'My Documents',
#  'My project',
#  'NetHood',
#  'node_modules',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
# ...

# %%
import os
os.chdir("Medical-Insurance-Project")
os.listdir()
# Out:
# ['.git', '.gitignore', 'LICENSE', 'README.md']
